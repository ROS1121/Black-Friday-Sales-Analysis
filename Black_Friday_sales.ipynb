# %% [markdown]
# # Black Friday - Walkthrough

# %%
import pandas as pd

# %%
df= pd.read_csv("BlackFriday.csv")        #df-dataframe, read_csv fun that read the data.

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.head(14)
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0   1000001  P00069042      F   0-17          10             A
# 1   1000001  P00248942      F   0-17          10             A
# 2   1000001  P00087842      F   0-17          10             A
# 3   1000001  P00085442      F   0-17          10             A
# 4   1000002  P00285442      M    55+          16             C
# 5   1000003  P00193542      M  26-35          15             A
# 6   1000004  P00184942      M  46-50           7             B
# 7   1000004  P00346142      M  46-50           7             B
# 8   1000004   P0097242      M  46-50           7             B
# 9   1000005  P00274942      M  26-35          20             A
# 10  1000005  P00251242      M  26-35          20             A
# 11  1000005  P00014542      M  26-35          20             A
# 12  1000005  P00031342      M  26-35          20             A
# 13  1000005  P00145042      M  26-35          20             A
#
# ...

# %%
df.info()             # basic info about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull()      # Checking which are null values
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 537572    False       False   False  False       False          False
# 537573    False       False   False  False       False          False
# 537574    False       False   False  False       False          False
# 537575    False       False   False  False       False          False
# 537576    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
df.isnull().sum()          # how many null values present in the dataset
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df.dropna()       # dropna() will drop/remove all rows which are having at least one null values
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 6       1000004  P00184942      M  46-50           7             B
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 537549  1004734  P00345842      M  51-55           1             B
# 537551  1004735  P00313442      M  46-50           3             C
# 537562  1004736  P00146742      M  18-25          20             A
# 537571  1004737  P00221442      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# ...

# %%
df.dropna().isnull().sum()     # Ucan see not any null values, but left with only 164278 rows out of 537577 rows.
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
# Now this is upto us, opt1: to remove all rows having null values and
# ... opt2: prd_cat-2,3 columns which are having mostly null values.
# We will GO With Opt 2 remove product cat 1 and 2.  so that we have now more than 80%   Let's Do /-

# %%
del df["Product_Category_2"]
del df["Product_Category_3"]

# %%
df    # as U see both category were deleted with not any null values
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# # L2: BlackFriday - Analysing Columns

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
# Its possible that one user purchase multiple items so that means there are not having 5Lakh users but less.
#... multiple items puchased by one user.
# For that purpose finding how many unique uses are  in the dataset currenlty /-

# %%
df["User_ID"].nunique()          # Means 5K 8hun 91 only unique users are in the dataset. # Accutual_users
# Out:
# 5891

# %%
df["User_ID"].unique()          # U see each unique id's of customers
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529])

# %%
df["Product_ID"].nunique()       # acctual unique products there
# Out:
# 3623

# %%
# So if concludes everything - all purchases done between 5891 users and 3623 products only/-

# %%
df['Gender'].unique()     # Genders only Male and Female
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["Age"].unique()    # total 7 age brackets
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df["Occupation"].unique()       # total 21 types of occupations
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
df["City_Category"].unique()    # A B C are the city categories
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["Stay_In_Current_City_Years"].unique()        # from how many years customers live in this city
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df["Marital_Status"].unique()   # Marital_Status
# Out:
# array([0, 1])

# %%
df['Product_Category_1'].unique()            # toal 18 types of Product categories are there in the dataset
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9])

# %%
# Total number of sales spend by the customers on this black friday sale
df['Purchase'].sum()
# Out:
# 5017668378

# %%
# Just count acctual numbers of sales on Black_friday in indian_format. 


def format_indian(num):
    if num >= 10000000:  # 1 Crore
        return f"₹{num/10000000:.2f} Cr"
    elif num >= 100000:   # 1 Lakh
        return f"₹{num/100000:.2f} L"
    elif num >= 1000:
        return f"₹{num/1000:.2f} K"
    else:
        return f"₹{num}"


total_sale = df['Purchase'].sum()
print(format_indian(total_sale))
# Out:
# ₹501.77 Cr

# %%
df['Purchase'].sum() / len(df['Purchase'])    # Average Purchase per user for their product
# Out:
# 9333.859852635065

# %%
# column names with uniqueness  

for column in df.columns:
    print(column, ":" ,df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %% [markdown]
# # L3: Analyzing Gender

# %% [markdown]
# #1 Let's analyse which Gender having more purchase during Black Friday sales

# %%
df[df["Gender"] == "M"]     #only male rows printed
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                              4+               0                   8
# ...

# %%
len(df[df["Gender"] == 'M']) , len(df[df["Gender"] == 'F'])   # how many male and female purchase something
# Out:
# (405380, 132197)

# %%
data = pd.DataFrame({"Ratio" : [len(df[df["Gender"] == 'M']) , len(df[df["Gender"] == 'F'])]}, index = ['Male', 'Female'])  # Dict

# %%
data    # created dict to know how many males and females
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
# Now going to plot piechart for this data of male and female

# %%
data.plot.pie(y = "Ratio",figsize = (5,5), autopct = "%.1f")
# Out:
# <Axes: ylabel='Ratio'>

# %%
# simple way of doing all this let's see

# %%
df.groupby('Gender').size().plot(kind = 'pie', 
                                autopct = '%.1f',
                                 title = "Gender Ratio", figsize = (5,5))
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df.groupby('Gender').size().plot(kind = 'bar', 
                                 title = "Gender Ratio", figsize = (5,5))  # BarGraph
# Out:
# <Axes: title={'center': 'Gender Ratio'}, xlabel='Gender'>

# %% [markdown]
# #2. Analysing how much both spend during black friday sale

# %%
df.groupby('Gender')['Purchase'].sum()   # This much of money both spend on purchasing
# Out:
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.groupby('Gender')['Purchase'].sum().plot(kind='pie', figsize = (5,5), autopct = '%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# #3. Per Product how much amount of money spend by male and female

# %%
df.groupby('Gender')['Purchase'].mean().plot(kind='pie', autopct = '%0.1f', title="Average Purchase per Product by Gender")
# almost same, male and female spend almost same amount per product
# Out:
# <Axes: title={'center': 'Average Purchase per Product by Gender'}, ylabel='Purchase'>

# %% [markdown]
# "Women = 25% of customers, but equal per-product spending"
#
# "We should maintain our male customer base while actively marketing to attract more female customers, as they represent a significant growth opportunity."

# %% [markdown]
# # L4: Analyzing Age and Marital Status

# %%
# Analysing which Age categories are more buying, married or not ?

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby('Age')['User_ID'].size()/1000   # Number of customers in each age brackets
# Out:
# Age
# 0-17      14.707
# 18-25     97.634
# 26-35    214.690
# 36-45    107.499
# 46-50     44.526
# 51-55     37.618
# 55+       20.903
# Name: User_ID, dtype: float64

# %%
(df.groupby('Age')['User_ID'].size()/1000).plot(kind='bar', figsize=(10,6), 
                                               title='Age-wise Customer Distribution')
# Out:
# <Axes: title={'center': 'Age-wise Customer Distribution'}, xlabel='Age'>

# %%
df.groupby("Age")['Purchase'].sum()/10000000     # Total money spend by each age brackets
# Out:
# Age
# 0-17      13.265901
# 18-25     90.166928
# 26-35    199.974911
# 36-45    101.064956
# 46-50     41.341822
# 51-55     36.190836
# 55+       19.761484
# Name: Purchase, dtype: float64

# %%
(df.groupby("Age")['Purchase'].sum() / 10000000).plot(kind='bar', figsize=(10,6), 
                                                       title="Purchase / Amount Distribution by Age (in Crores)")
# Out:
# <Axes: title={'center': 'Purchase / Amount Distribution by Age (in Crores)'}, xlabel='Age'>

# %% [markdown]
# > Our core customer is aged 26-35, contributing 34% of total sales. Young adults (26-35) are our biggest spenders, but we're losing customers after 45 - so we must retain older customers and attract the next generation (18-25).

# %%
#  How many unique products people are purchasing ?

# %%
df["Product_ID"].nunique()      # 3623 number of unique products are there
# Out:
# 3623

# %%
for i in df['Age'].unique():
    print(i)
# Out:
# 0-17
# 55+
# 26-35
# 46-50
# 51-55
# 36-45
# 18-25

# %%
df[df['Age'] == i]# Product purchase by 0-17 age grp
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 70      1000018  P00366542      F  18-25           3             B
# 71      1000018  P00190742      F  18-25           3             B
# 72      1000018  P00151842      F  18-25           3             B
# 73      1000018  P00112642      F  18-25           3             B
# 74      1000018  P00118442      F  18-25           3             B
# ...         ...        ...    ...    ...         ...           ...
# 537566  1004736  P00048742      M  18-25          20             A
# 537567  1004736  P00157542      M  18-25          20             A
# 537568  1004736  P00250642      M  18-25          20             A
# 537569  1004736  P00023142      M  18-25          20             A
# 537570  1004736  P00162442      M  18-25          20             A
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 70                              3               0                   5
# ...

# %%
for i in df['Age'].unique():
    print(i,":", len(df[df["Age"]==i]))    # Total number of Purchases happend.
# Out:
# 0-17 : 14707
# 55+ : 20903
# 26-35 : 214690
# 46-50 : 44526
# 51-55 : 37618
# 36-45 : 107499
# 18-25 : 97634

# %%
df.groupby("Age")["User_ID"].nunique()   # Unique customers in each bracket.
# Out:
# Age
# 0-17      218
# 18-25    1069
# 26-35    2053
# 36-45    1167
# 46-50     531
# 51-55     481
# 55+       372
# Name: User_ID, dtype: int64

# %%
df.groupby("Age")["Product_ID"].nunique()   # Unique products brought by customers in each age bracket.
# Out:
# Age
# 0-17     2300
# 18-25    3213
# 26-35    3419
# 36-45    3318
# 46-50    3099
# 51-55    2877
# 55+      2573
# Name: Product_ID, dtype: int64

# %%
summary = df.groupby('Age').agg(                                     #Summary.
    unique_customers=('User_ID', 'nunique'),
    unique_products=('Product_ID', 'nunique'),
    total_no_of_purchases=('User_ID', 'count'),
    total_sales=('Purchase', lambda x: x.sum() / 10000000) ,
        
)

print(summary)
# Out:
#        unique_customers  unique_products  total_no_of_purchases  total_sales
# Age
# 0-17                218             2300                  14707    13.265901
# 18-25              1069             3213                  97634    90.166928
# 26-35              2053             3419                 214690   199.974911
# 36-45              1167             3318                 107499   101.064956
# 46-50               531             3099                  44526    41.341822
# 51-55               481             2877                  37618    36.190836
# 55+                 372             2573                  20903    19.761484

# %%
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
# How many different products each age group bought, and makes a bar chart to visualize it.
lst = []
for i in df['Age'].unique():
    lst.append([i, df[df["Age"] == i ]['Product_ID'].nunique()])
data = pd.DataFrame(lst, columns = ['Age', 'Products'])

# %%
data.plot.bar(x = 'Age', figsize=(8,6))
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby('Age')['Product_ID'].nunique().plot.bar(figsize=(3,3)) # do the same thing but with code
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# "How Much Each Age Group Spends on Average"

# %%
 # "How Much Each Age Group Spends on Average"
df.groupby('Age')["Purchase"].mean().plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Marital_Status').size().plot(kind='pie', autopct = '%0.1f')   # overall marital status
# Out:
# <Axes: >

# %%
# Gender wise marital_status.

df_labeled = df.copy()
df_labeled['Marital_Status'] = df_labeled['Marital_Status'].map({0: 'Single', 1: 'Married'})


df_labeled.groupby(['Marital_Status', 'Gender']).size().unstack().plot(kind='pie', 
                                                                        subplots=True,
                                                                        autopct='%0.1f',
                                                                        labels=['Single', 'Married'],
                                                                        figsize=(10,5))
plt.suptitle('Marital Status by Gender')
plt.show()

# %% [markdown]
# # L5. Multi column analysis

# %%
import pandas as pd
import seaborn as sns

# %%
# Analyse how much male and female are purchasing.

# %%
sns.set(rc = {"figure.figsize":(12,6)})
sns.countplot(x = "Age", hue = "Gender", data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {"figure.figsize":(12,6)})
sns.countplot(x = "Gender", hue = "Age", data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind='pie', autopct = '%0.1f')   #customers belongs to which city
# Out:
# <Axes: >

# %%
sns.countplot(x = 'City_Category',hue = 'Age', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = 'Age',hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = 'Marital_Status',hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x = 'City_Category',hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category')['Purchase'].sum().plot(kind = 'pie',autopct = '%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
# Totally different scenario in terms of avg pricing for purchasing 
df.groupby('City_Category')['Purchase'].mean().plot(kind = 'pie',autopct = '%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# # L6 Occupation and Products Analysis

# %%
# Occupation-Based Product Analysis: Who Buys What?
